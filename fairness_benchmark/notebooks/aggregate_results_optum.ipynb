# %%
import numpy as np
import pandas as pd
import os
import glob
import torch
import torch.nn.functional as F
import joblib
import itertools
import scipy
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
import string
from sklearn.metrics import roc_auc_score, average_precision_score, brier_score_loss, recall_score, precision_score
from prediction_utils.util import df_dict_concat, yaml_read
from matplotlib.ticker import FormatStrFormatter

# %%
project_dir = "/share/pi/nigam/projects/spfohl/cohorts/admissions/optum"
experiment_name_baseline = 'baseline_tuning_fold_1'
experiment_name_fair = 'fair_tuning_fold_1'
tasks = ['LOS_7', 'readmission_30']
cohort_path = os.path.join(project_dir, 'cohort', 'cohort.parquet')
row_id_map_path = os.path.join(
    project_dir, 'merged_features_binary/features_sparse/features_row_id_map.parquet'
)
result_path = os.path.join(project_dir, 'experiments', 'merged_results_fold_1')
os.makedirs(result_path, exist_ok=True)

# %%
attributes = ['gender_concept_name', 'age_group']

# %%
cohort = pd.read_parquet(cohort_path)
row_id_map = pd.read_parquet(row_id_map_path)
cohort = cohort.merge(row_id_map)

# %% [markdown]
# ### Generate the cohort table

# %%
### Cohort table
cohort_df_long = (
    cohort
    .melt(
        id_vars = ['person_id'] + attributes,
        value_vars = tasks,
        var_name = 'task',
        value_name = 'labels'
    )
    .melt(
        id_vars = ['person_id', 'task', 'labels'],
        value_vars = attributes,
        var_name = 'attribute',
        value_name = 'group'
    )
)

# %%
cohort_statistics_df = (
    cohort_df_long
    .groupby(['task', 'attribute', 'group'])
    .agg(
        prevalence=('labels', 'mean'),
    )
    .reset_index()
    .groupby('attribute')
    .apply(lambda x: x.pivot_table(index = 'group', columns = 'task', values = 'prevalence'))
    .reset_index()
)

group_size_df = (
    cohort_df_long
    .groupby(['task', 'attribute', 'group'])
    .agg(
        size = ('labels', lambda x: x.shape[0])
    )
    .reset_index()
    .drop(columns = 'task')
    .drop_duplicates()
)

cohort_statistics_df = cohort_statistics_df.merge(group_size_df)
cohort_statistics_df = (
    cohort_statistics_df
    .set_index(['attribute', 'group'])
    [['size'] + tasks]
)

# %%
cohort_statistics_df
# Out:
#                                             size     LOS_7  readmission_30
# attribute           group
# age_group           [18-30)              1067423  0.060803        0.034595
#                     [30-45)              1854239  0.061145        0.034738
#                     [45-55)              1006924  0.137928        0.061149
#                     [55-65)              1173140  0.195259        0.080777
#                     [65-75)              1294273  0.257880        0.100376
#                     [75-91)              1678572  0.385770        0.168239
# gender_concept_name FEMALE               5040564  0.168399        0.076470
#                     MALE                 3032831  0.223706        0.093776
#                     No matching concept     1176  0.213435        0.111395

# %%
## Write to Latex
table_path = './../figures/optum'
os.makedirs(table_path, exist_ok=True)
with open(os.path.join(table_path, 'cohort_table.txt'), 'w') as fp:
    (
        cohort_statistics_df
        .reset_index().drop(columns='attribute').set_index(['group'])
        .to_latex(
            fp, 
            float_format = '%.3g', 
            index_names = False, 
            index=True
        )
    )

# %% [markdown]
# ### Get the results

# %%
def get_result_df_baseline(base_path, filename='result_df_group_standard_eval.parquet'):
    """
    Gets the results for training the baseline models
    """
    selected_models_path = os.path.join(
        base_path, 
        'config',
        'selected_models', '**', '*.yaml'
    )
    selected_models_dict = {
        filename.split('/')[-2]: filename.split('/')[-1]
        for filename in glob.glob(selected_models_path, recursive=True)
    }
    paths = [
        glob.glob(
            os.path.join(
                base_path,
                'performance',
                task, 
                config_filename, 
                '**', 
                filename
            ),
            recursive=True
        )
        for task, config_filename in selected_models_dict.items()
    ]
    paths = list(itertools.chain(*paths))
    result_df_baseline = df_dict_concat(
        {
            tuple(filename.split('/'))[-4:-1]:
            pd.read_parquet(filename)
            for filename in paths
        },
        ['task2', 'config_filename', 'fold_id']
    ).drop(columns='task2')
    return result_df_baseline

# %%
result_df_baseline = get_result_df_baseline(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_baseline,  
    )
)

# %%
result_df_baseline.task.unique()
# Out:
# array(['LOS_7', 'readmission_30'], dtype=object)

# %%
result_df_baseline.task.unique()
# Out:
# array(['LOS_7', 'readmission_30'], dtype=object)

# %%
result_df_calibration_baseline = get_result_df_baseline(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_baseline,  
    ),
    filename='calibration_result.parquet'
)
id_vars = ['fold_id', 'phase', 'config_filename', 'task', 'attribute', 'group']
result_df_calibration_baseline = result_df_calibration_baseline.melt(
    id_vars = id_vars,
    value_vars = set(result_df_calibration_baseline.columns) - set(id_vars),
    var_name = 'metric',
    value_name = 'performance'
).query('metric != "brier"')

# %%
result_df_calibration_baseline.metric.unique()
# Out:
# array(['brier_signed', 'calib_error_signed', 'calib_group_error_signed',
#        'calib_error', 'calib_group_error'], dtype=object)

# %%
# Import fair_ova metrics
result_df_ova_baseline = get_result_df_baseline(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_baseline,  
    ),
    filename='result_df_group_fair_ova.parquet'
)
id_vars = ['fold_id', 'phase', 'config_filename', 'task', 'attribute', 'group']
result_df_ova_baseline = result_df_ova_baseline.melt(
    id_vars = id_vars,
    value_vars = set(result_df_ova_baseline.columns) - set(id_vars),
    var_name = 'metric',
    value_name = 'performance'
)

# %%
result_df_baseline = pd.concat([result_df_baseline, result_df_calibration_baseline, result_df_ova_baseline], ignore_index=True)
# result_df_baseline = pd.concat([result_df_baseline, result_df_ova_baseline], ignore_index=True)

# %%
result_df_baseline
# Out:
#     config_filename fold_id           metric phase            task  \
# 0            2.yaml       1              auc  test           LOS_7
# 1            2.yaml       1              auc  test           LOS_7
# 2            2.yaml       1              auc  test           LOS_7
# 3            2.yaml       1              auc  test           LOS_7
# 4            2.yaml       1              auc  test           LOS_7
# ..              ...     ...              ...   ...             ...
# 603          2.yaml       1  mean_prediction   val  readmission_30
# 604          2.yaml       1  mean_prediction   val  readmission_30
# 605          2.yaml       1  mean_prediction   val  readmission_30
# 606          2.yaml       1  mean_prediction   val  readmission_30
# 607          2.yaml       1  mean_prediction   val  readmission_30
#
#                attribute    group  performance  performance_overall
# 0              age_group  [18-30)     0.840362             0.802328
# 1              age_group  [30-45)     0.826019             0.802328
# 2              age_group  [45-55)     0.724967             0.802328
# 3              age_group  [55-65)     0.710528             0.802328
# 4              age_group  [65-75)     0.709761             0.802328
# ..                   ...      ...          ...                  ...
# 603            age_group  [65-75)     0.021172                  NaN
# 604            age_group  [55-65)    -0.001764                  NaN
# 605            age_group  [45-55)    -0.018385                  NaN
# 606  gender_concept_name     MALE     0.010943                  NaN
# 607  gender_concept_name   FEMALE    -0.006564                  NaN
#
# [608 rows x 9 columns]

# %%
def flatten_multicolumns(df):
    """
    Converts multi-index columns into single colum
    """
    df.columns = ['_'.join([el for el in col if el != '']).strip() for col in df.columns.values if len(col) > 1]
    return df

# %%
result_df_baseline_mean = (
    result_df_baseline
    .groupby(list(set(result_df_baseline.columns) - {'fold_id', 'performance', 'performance_overall'}))
    [['performance', 'performance_overall']]
    .agg(['mean', 'std', 'sem'])
    .reset_index()
)
result_df_baseline_mean = result_df_baseline_mean.rename(
    columns={
        'performance': 'performance_baseline',
        'performance_overall': 'performance_overall_baseline'
    }
)
result_df_baseline_mean = flatten_multicolumns(result_df_baseline_mean)

# %%
result_df_baseline_mean
# Out:
#        group config_filename            attribute phase      metric  \
# 0     FEMALE          2.yaml  gender_concept_name  test         auc
# 1     FEMALE          2.yaml  gender_concept_name  test         auc
# 2     FEMALE          2.yaml  gender_concept_name  test       auprc
# 3     FEMALE          2.yaml  gender_concept_name  test       auprc
# 4     FEMALE          2.yaml  gender_concept_name  test       brier
# ..       ...             ...                  ...   ...         ...
# 603  [75-91)          2.yaml            age_group   val      xauc_1
# 604  [75-91)          2.yaml            age_group   val  xauc_ova_0
# 605  [75-91)          2.yaml            age_group   val  xauc_ova_0
# 606  [75-91)          2.yaml            age_group   val  xauc_ova_1
# 607  [75-91)          2.yaml            age_group   val  xauc_ova_1
#
#                task  performance_baseline_mean  performance_baseline_std  \
# 0             LOS_7                   0.839665                       NaN
# 1    readmission_30                   0.794727                       NaN
# 2             LOS_7                   0.513063                       NaN
# 3    readmission_30                   0.258544                       NaN
# 4             LOS_7                   0.106802                       NaN
# ..              ...                        ...                       ...
# 603  readmission_30                   0.912136                       NaN
# 604           LOS_7                   0.533867                       NaN
# 605  readmission_30                   0.546223                       NaN
# 606           LOS_7                   0.892120                       NaN
# 607  readmission_30                   0.867252                       NaN
#
#      performance_baseline_sem  performance_overall_baseline_mean  \
# 0                         NaN                           0.802328
# 1                         NaN                           0.774163
# 2                         NaN                           0.496130
# 3                         NaN                           0.256986
# 4                         NaN                           0.122795
# ..                        ...                                ...
# 603                       NaN                                NaN
# 604                       NaN                                NaN
# 605                       NaN                                NaN
# 606                       NaN                                NaN
# 607                       NaN                                NaN
#
#      performance_overall_baseline_std  performance_overall_baseline_sem
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ..                                ...                               ...
# 603                               NaN                               NaN
# 604                               NaN                               NaN
# 605                               NaN                               NaN
# 606                               NaN                               NaN
# 607                               NaN                               NaN
#
# [608 rows x 12 columns]

# %%
result_df_baseline_mean.task.unique()
# Out:
# array(['LOS_7', 'readmission_30'], dtype=object)

# %%
def get_result_df_fair(base_path=None, filename='result_df_group_standard_eval.parquet', paths=None):
    if paths is None:
        performance_path = os.path.join(
            base_path,
            'performance',
        )
        paths = glob.glob(os.path.join(performance_path, '**', filename), recursive=True)
    result_df_fair = df_dict_concat(
        {
            tuple(file_name.split('/'))[-5:-1]:
            pd.read_parquet(file_name)
            for file_name in paths
        },
        ['task2', 'sensitive_attribute', 'config_filename', 'fold_id']
    ).drop(columns='task2')
    return result_df_fair

# %%
# Fair results
result_df_fair = get_result_df_fair(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_fair
    )
)

# %%
# List config_filenames without a result
(
    result_df_fair
    .groupby(
        list(set(result_df_fair.columns) - set(['fold_id', 'performance', 'performance_overall']))
    )
    .agg(lambda x: len(x))
    .query("fold_id != 1")
    .reset_index()
    .config_filename
    .sort_values()
    .unique()
)
# Out:
# array([], dtype=float64)

# %%
result_df_calibration_fair = get_result_df_fair(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_fair
    ),
    filename='calibration_result.parquet'
)

id_vars = ['fold_id', 'phase', 'config_filename', 'task', 'sensitive_attribute', 'attribute', 'group']
result_df_calibration_fair = result_df_calibration_fair.melt(
    id_vars = id_vars,
    value_vars = set(result_df_calibration_fair.columns) - set(id_vars),
    var_name = 'metric',
    value_name = 'performance'
).query('metric != "brier"')

# %%
result_df_calibration_fair.query(
    """
    task == "LOS_7" & sensitive_attribute == "gender_concept_name" & metric == "calib_group_error" & group == "FEMALE" & phase == "test"
    """
)
# Out:
#       fold_id phase config_filename   task  sensitive_attribute  \
# 19206       1  test          8.yaml  LOS_7  gender_concept_name
# 19222       1  test         37.yaml  LOS_7  gender_concept_name
# 19238       1  test         36.yaml  LOS_7  gender_concept_name
# 19254       1  test          0.yaml  LOS_7  gender_concept_name
# 19270       1  test         35.yaml  LOS_7  gender_concept_name
# 19286       1  test          1.yaml  LOS_7  gender_concept_name
# 19302       1  test          3.yaml  LOS_7  gender_concept_name
# 19318       1  test         13.yaml  LOS_7  gender_concept_name
# 19334       1  test         51.yaml  LOS_7  gender_concept_name
# 19350       1  test         33.yaml  LOS_7  gender_concept_name
# 19366       1  test          9.yaml  LOS_7  gender_concept_name
# 19382       1  test         25.yaml  LOS_7  gender_concept_name
# 19398       1  test          4.yaml  LOS_7  gender_concept_name
# 19414       1  test         43.yaml  LOS_7  gender_concept_name
# 19430       1  test         27.yaml  LOS_7  gender_concept_name
# 19446       1  test         19.yaml  LOS_7  gender_concept_name
# 19462       1  test         50.yaml  LOS_7  gender_concept_name
# 19478       1  test         55.yaml  LOS_7  gender_concept_name
# 19494       1  test         28.yaml  LOS_7  gender_concept_name
# 19510       1  test         17.yaml  LOS_7  gender_concept_name
# 19526       1  test         42.yaml  LOS_7  gender_concept_name
# 19542       1  test         22.yaml  LOS_7  gender_concept_name
# 19558       1  test         20.yaml  LOS_7  gender_concept_name
# 19574       1  test         11.yaml  LOS_7  gender_concept_name
# 19590       1  test          7.yaml  LOS_7  gender_concept_name
# 19606       1  test          2.yaml  LOS_7  gender_concept_name
# 19622       1  test         54.yaml  LOS_7  gender_concept_name
# 19638       1  test         10.yaml  LOS_7  gender_concept_name
# 19654       1  test         16.yaml  LOS_7  gender_concept_name
# 19670       1  test         46.yaml  LOS_7  gender_concept_name
# 19686       1  test         23.yaml  LOS_7  gender_concept_name
# 19702       1  test         56.yaml  LOS_7  gender_concept_name
# 19718       1  test         48.yaml  LOS_7  gender_concept_name
# 19734       1  test         18.yaml  LOS_7  gender_concept_name
# 19750       1  test         21.yaml  LOS_7  gender_concept_name
# 19766       1  test         29.yaml  LOS_7  gender_concept_name
# 19782       1  test         59.yaml  LOS_7  gender_concept_name
# 19798       1  test         12.yaml  LOS_7  gender_concept_name
# 19814       1  test         53.yaml  LOS_7  gender_concept_name
# 19830       1  test         44.yaml  LOS_7  gender_concept_name
# 19846       1  test         31.yaml  LOS_7  gender_concept_name
# 19862       1  test         34.yaml  LOS_7  gender_concept_name
# 19878       1  test         39.yaml  LOS_7  gender_concept_name
# 19894       1  test         41.yaml  LOS_7  gender_concept_name
# 19910       1  test         47.yaml  LOS_7  gender_concept_name
# 19926       1  test         24.yaml  LOS_7  gender_concept_name
# 19942       1  test         14.yaml  LOS_7  gender_concept_name
# 19958       1  test         38.yaml  LOS_7  gender_concept_name
# 19974       1  test          6.yaml  LOS_7  gender_concept_name
# 19990       1  test         32.yaml  LOS_7  gender_concept_name
# 20006       1  test         45.yaml  LOS_7  gender_concept_name
# 20022       1  test         26.yaml  LOS_7  gender_concept_name
# 20038       1  test         30.yaml  LOS_7  gender_concept_name
# 20054       1  test         58.yaml  LOS_7  gender_concept_name
# 20070       1  test         15.yaml  LOS_7  gender_concept_name
# 20086       1  test         40.yaml  LOS_7  gender_concept_name
# 20102       1  test         57.yaml  LOS_7  gender_concept_name
# 20118       1  test         52.yaml  LOS_7  gender_concept_name
# 20134       1  test          5.yaml  LOS_7  gender_concept_name
# 20150       1  test         49.yaml  LOS_7  gender_concept_name
#
#                  attribute   group             metric   performance
# 19206  gender_concept_name  FEMALE  calib_group_error  7.931658e-06
# 19222  gender_concept_name  FEMALE  calib_group_error  9.581342e-04
# 19238  gender_concept_name  FEMALE  calib_group_error  9.366479e-04
# 19254  gender_concept_name  FEMALE  calib_group_error  5.450435e-07
# 19270  gender_concept_name  FEMALE  calib_group_error  2.671223e-05
# 19286  gender_concept_name  FEMALE  calib_group_error  8.002997e-07
# 19302  gender_concept_name  FEMALE  calib_group_error  9.040098e-06
# 19318  gender_concept_name  FEMALE  calib_group_error  5.477610e-05
# 19334  gender_concept_name  FEMALE  calib_group_error  4.443074e-04
# 19350  gender_concept_name  FEMALE  calib_group_error  8.153347e-05
# 19366  gender_concept_name  FEMALE  calib_group_error  3.366717e-06
# 19382  gender_concept_name  FEMALE  calib_group_error  4.879118e-04
# 19398  gender_concept_name  FEMALE  calib_group_error  4.974112e-06
# 19414  gender_concept_name  FEMALE  calib_group_error  9.532767e-04
# 19430  gender_concept_name  FEMALE  calib_group_error  1.066927e-05
# 19446  gender_concept_name  FEMALE  calib_group_error  2.513765e-04
# 19462  gender_concept_name  FEMALE  calib_group_error  5.207764e-05
# 19478  gender_concept_name  FEMALE  calib_group_error  8.315773e-04
# 19494  gender_concept_name  FEMALE  calib_group_error  2.684063e-06
# 19510  gender_concept_name  FEMALE  calib_group_error  4.135908e-06
# 19526  gender_concept_name  FEMALE  calib_group_error  1.159088e-03
# 19542  gender_concept_name  FEMALE  calib_group_error  3.156953e-06
# 19558  gender_concept_name  FEMALE  calib_group_error  1.170078e-05
# 19574  gender_concept_name  FEMALE  calib_group_error  4.323141e-06
# 19590  gender_concept_name  FEMALE  calib_group_error  1.045994e-05
# 19606  gender_concept_name  FEMALE  calib_group_error  6.542721e-06
# 19622  gender_concept_name  FEMALE  calib_group_error  9.701728e-04
# 19638  gender_concept_name  FEMALE  calib_group_error  3.873992e-06
# 19654  gender_concept_name  FEMALE  calib_group_error  2.404759e-06
# 19670  gender_concept_name  FEMALE  calib_group_error  6.660116e-04
# 19686  gender_concept_name  FEMALE  calib_group_error  4.958354e-06
# 19702  gender_concept_name  FEMALE  calib_group_error  5.949398e-05
# 19718  gender_concept_name  FEMALE  calib_group_error  1.117048e-03
# 19734  gender_concept_name  FEMALE  calib_group_error  2.206707e-04
# 19750  gender_concept_name  FEMALE  calib_group_error  1.784844e-06
# 19766  gender_concept_name  FEMALE  calib_group_error  1.250092e-05
# 19782  gender_concept_name  FEMALE  calib_group_error  9.836108e-05
# 19798  gender_concept_name  FEMALE  calib_group_error  7.028620e-05
# 19814  gender_concept_name  FEMALE  calib_group_error  1.005437e-04
# 19830  gender_concept_name  FEMALE  calib_group_error  3.793634e-05
# 19846  gender_concept_name  FEMALE  calib_group_error  7.984086e-04
# 19862  gender_concept_name  FEMALE  calib_group_error  4.825646e-05
# 19878  gender_concept_name  FEMALE  calib_group_error  3.243833e-04
# 19894  gender_concept_name  FEMALE  calib_group_error  4.938817e-05
# 19910  gender_concept_name  FEMALE  calib_group_error  7.846712e-05
# 19926  gender_concept_name  FEMALE  calib_group_error  4.519681e-04
# 19942  gender_concept_name  FEMALE  calib_group_error  8.851241e-06
# 19958  gender_concept_name  FEMALE  calib_group_error  4.273849e-05
# 19974  gender_concept_name  FEMALE  calib_group_error  7.464010e-06
# 19990  gender_concept_name  FEMALE  calib_group_error  2.806319e-05
# 20006  gender_concept_name  FEMALE  calib_group_error  5.166612e-04
# 20022  gender_concept_name  FEMALE  calib_group_error  1.597107e-05
# 20038  gender_concept_name  FEMALE  calib_group_error  6.746761e-04
# 20054  gender_concept_name  FEMALE  calib_group_error  8.436376e-04
# 20070  gender_concept_name  FEMALE  calib_group_error  2.359575e-06
# 20086  gender_concept_name  FEMALE  calib_group_error  2.770984e-04
# 20102  gender_concept_name  FEMALE  calib_group_error  3.926225e-04
# 20118  gender_concept_name  FEMALE  calib_group_error  8.588469e-04
# 20134  gender_concept_name  FEMALE  calib_group_error  4.111591e-06
# 20150  gender_concept_name  FEMALE  calib_group_error  9.340641e-04

# %%
result_df_ova_fair = get_result_df_fair(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_fair
    ),
    filename='result_df_group_fair_ova.parquet'
)

id_vars = ['fold_id', 'phase', 'config_filename', 'task', 'sensitive_attribute', 'attribute', 'group']
result_df_ova_fair = result_df_ova_fair.melt(
    id_vars = id_vars,
    value_vars = set(result_df_ova_fair.columns) - set(id_vars),
    var_name = 'metric',
    value_name = 'performance'
)

# %%
result_df_calibration_fair.query('metric == "calib_group_error"')
# Out:
#       fold_id phase config_filename            task  sensitive_attribute  \
# 19200       1  test          8.yaml           LOS_7  gender_concept_name
# 19201       1  test          8.yaml           LOS_7  gender_concept_name
# 19202       1  test          8.yaml           LOS_7  gender_concept_name
# 19203       1  test          8.yaml           LOS_7  gender_concept_name
# 19204       1  test          8.yaml           LOS_7  gender_concept_name
# ...       ...   ...             ...             ...                  ...
# 23035       1   val         49.yaml  readmission_30            age_group
# 23036       1   val         49.yaml  readmission_30            age_group
# 23037       1   val         49.yaml  readmission_30            age_group
# 23038       1   val         49.yaml  readmission_30            age_group
# 23039       1   val         49.yaml  readmission_30            age_group
#
#                  attribute    group             metric  performance
# 19200            age_group  [18-30)  calib_group_error     0.000524
# 19201            age_group  [30-45)  calib_group_error     0.000811
# 19202            age_group  [45-55)  calib_group_error     0.000456
# 19203            age_group  [55-65)  calib_group_error     0.000146
# 19204            age_group  [65-75)  calib_group_error     0.000008
# ...                    ...      ...                ...          ...
# 23035            age_group  [55-65)  calib_group_error     0.000018
# 23036            age_group  [65-75)  calib_group_error     0.000198
# 23037            age_group  [75-91)  calib_group_error     0.006054
# 23038  gender_concept_name   FEMALE  calib_group_error     0.000041
# 23039  gender_concept_name     MALE  calib_group_error     0.000112
#
# [3840 rows x 9 columns]

# %%
result_df_fair = pd.concat([result_df_fair, result_df_calibration_fair, result_df_ova_fair], ignore_index=True)
# result_df_fair = pd.concat([result_df_fair, result_df_ova_fair], ignore_index=True)

# %%
result_df_fair_mean = (
    result_df_fair
    .groupby(list(set(result_df_fair.columns) - set(['fold_id', 'performance', 'performance_overall'])))
    [['performance', 'performance_overall']]
    .agg(['mean', 'std', 'sem'])
    .reset_index()
)
result_df_fair_mean = flatten_multicolumns(result_df_fair_mean)

# %%
ci_func = lambda x: x * 1.96
result_df_fair_mean = result_df_fair_mean.assign(
    performance_CI = lambda x: ci_func(x['performance_sem']),
    performance_overall_CI = lambda x: ci_func(x['performance_overall_sem']),
)

# %%
def label_fair_mode(df):
    df['fair_mode'] = (
    df['regularization_metric']
    .where(~df['regularization_metric'].str.match('mmd'), 
           df['regularization_metric'].astype(str) + '_' + df['mmd_mode'].astype(str), 
           axis=0)
    )
    df['fair_mode'] = (
        df['fair_mode']
        .where(~df['fair_mode'].str.match('mean_prediction'), 
               df['fair_mode'].astype(str) + '_' + df['mean_prediction_mode'].astype(str), 
               axis=0
              )
    )
    return df

# %%
def get_fair_config_df(base_path):
    config_path = os.path.join(
        base_path,
        'config',
    )
    fair_config_files = glob.glob(
        os.path.join(config_path, '**', '*.yaml'),
        recursive=True
    )
    fair_config_dict_dict = {
        tuple(file_name.split('/'))[-2:]:
        yaml_read(file_name)
        for file_name in fair_config_files
    }

    fair_config_df = df_dict_concat(
        {
            key: pd.DataFrame(value, index=[key])
            for key, value in fair_config_dict_dict.items()
        },
        ['task', 'config_filename']
    )
    fair_config_df = label_fair_mode(fair_config_df)[['task', 'config_filename', 'fair_mode', 'lambda_group_regularization']]
    return fair_config_df

# %%
fair_config_df = get_fair_config_df(
    os.path.join(
        project_dir,
        'experiments',
        experiment_name_fair
    )
)

# %%
fair_config_df
# Out:
#                task config_filename                        fair_mode  \
# 0             LOS_7          8.yaml  mean_prediction_conditional_pos
# 1             LOS_7         37.yaml    mean_prediction_unconditional
# 2             LOS_7         36.yaml      mean_prediction_conditional
# 3             LOS_7          0.yaml      mean_prediction_conditional
# 4             LOS_7         35.yaml              mmd_conditional_pos
# ..              ...             ...                              ...
# 115  readmission_30         40.yaml                mmd_unconditional
# 116  readmission_30         57.yaml                  mmd_conditional
# 117  readmission_30         52.yaml                mmd_unconditional
# 118  readmission_30          5.yaml              mmd_conditional_pos
# 119  readmission_30         49.yaml    mean_prediction_unconditional
#
#      lambda_group_regularization
# 0                       0.002783
# 1                       0.464159
# 2                       0.464159
# 3                       0.001000
# 4                       0.166810
# ..                           ...
# 115                     0.464159
# 116                    10.000000
# 117                     3.593814
# 118                     0.001000
# 119                     3.593814
#
# [120 rows x 4 columns]

# %%
result_df_fair_mean.task.unique()
# Out:
# array(['LOS_7', 'readmission_30'], dtype=object)

# %%
result_df = pd.merge(result_df_baseline_mean.drop(columns='config_filename'), result_df_fair_mean,
                    how='outer', indicator=True).merge(fair_config_df)
assert result_df_fair_mean.shape[0] == result_df.shape[0]
result_df.head()
# Out:
#     group            attribute phase metric   task  performance_baseline_mean  \
# 0  FEMALE  gender_concept_name  test    auc  LOS_7                   0.839665
# 1  FEMALE  gender_concept_name  test    auc  LOS_7                   0.839665
# 2  FEMALE  gender_concept_name  test  auprc  LOS_7                   0.513063
# 3  FEMALE  gender_concept_name  test  auprc  LOS_7                   0.513063
# 4  FEMALE  gender_concept_name  test  brier  LOS_7                   0.106802
#
#    performance_baseline_std  performance_baseline_sem  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    performance_overall_baseline_mean  performance_overall_baseline_std  ...  \
# 0                           0.802328                               NaN  ...
# 1                           0.802328                               NaN  ...
# 2                           0.496130                               NaN  ...
# 3                           0.496130                               NaN  ...
# 4                           0.122795                               NaN  ...
#
#    performance_std performance_sem performance_overall_mean  \
# 0              NaN             NaN                 0.801219
# 1              NaN             NaN                 0.802113
# 2              NaN             NaN                 0.494226
# 3              NaN             NaN                 0.495495
# 4              NaN             NaN                 0.123059
#
#    performance_overall_std  performance_overall_sem  performance_CI  \
# 0                      NaN                      NaN             NaN
# 1                      NaN                      NaN             NaN
# 2                      NaN                      NaN             NaN
# 3                      NaN                      NaN             NaN
# 4                      NaN                      NaN             NaN
#
#    performance_overall_CI  _merge                    fair_mode  \
# 0                     NaN    both  mean_prediction_conditional
# 1                     NaN    both  mean_prediction_conditional
# 2                     NaN    both  mean_prediction_conditional
# 3                     NaN    both  mean_prediction_conditional
# 4                     NaN    both  mean_prediction_conditional
#
#    lambda_group_regularization
# 0                        0.001
# 1                        0.001
# 2                        0.001
# 3                        0.001
# 4                        0.001
#
# [5 rows x 24 columns]

# %%
result_df.query('_merge == "right_only"')
# Out:
# Empty DataFrame
# Columns: [group, attribute, phase, metric, task, performance_baseline_mean, performance_baseline_std, performance_baseline_sem, performance_overall_baseline_mean, performance_overall_baseline_std, performance_overall_baseline_sem, config_filename, sensitive_attribute, performance_mean, performance_std, performance_sem, performance_overall_mean, performance_overall_std, performance_overall_sem, performance_CI, performance_overall_CI, _merge, fair_mode, lambda_group_regularization]
# Index: []
#
# [0 rows x 24 columns]

# %%
result_df.metric.unique()
# Out:
# array(['auc', 'auprc', 'brier', 'brier_signed', 'calib_error',
#        'calib_error_signed', 'calib_group_error',
#        'calib_group_error_signed', 'emd_ova', 'emd_ova_0', 'emd_ova_1',
#        'loss_bce', 'mean_prediction', 'mean_prediction_0',
#        'mean_prediction_1', 'xauc_0', 'xauc_1', 'xauc_ova_0',
#        'xauc_ova_1'], dtype=object)

# %%
result_df = result_df.query('phase == "test"')

# %%
result_df.query(
    """
    task == "LOS_7" & sensitive_attribute == "gender_concept_name" & metric == "calib_group_error" & group == "FEMALE" & phase == "test"
    """
)['performance_mean']
# Out:
# 13       5.450435e-07
# 621      8.002997e-07
# 1229     3.873992e-06
# 1837     4.323141e-06
# 2445     7.028620e-05
# 3053     5.477610e-05
# 3661     8.851241e-06
# 4269     2.359575e-06
# 4877     2.404759e-06
# 5485     4.135908e-06
# 6093     2.206707e-04
# 6701     2.513765e-04
# 7309     6.542721e-06
# 7917     1.170078e-05
# 8525     1.784844e-06
# 9133     3.156953e-06
# 9741     4.958354e-06
# 10349    4.519681e-04
# 10957    4.879118e-04
# 11565    1.597107e-05
# 12173    1.066927e-05
# 12781    2.684063e-06
# 13389    1.250092e-05
# 13997    9.040098e-06
# 14605    6.746761e-04
# 15213    7.984086e-04
# 15821    2.806319e-05
# 16429    8.153347e-05
# 17037    4.825646e-05
# 17645    2.671223e-05
# 18253    9.366479e-04
# 18861    9.581342e-04
# 19469    4.273849e-05
# 20077    3.243833e-04
# 20685    4.974112e-06
# 21293    2.770984e-04
# 21901    4.938817e-05
# 22509    1.159088e-03
# 23117    9.532767e-04
# 23725    3.793634e-05
# 24333    5.166612e-04
# 24941    6.660116e-04
# 25549    7.846712e-05
# 26157    1.117048e-03
# 26765    9.340641e-04
# 27373    4.111591e-06
# 27981    5.207764e-05
# 28589    4.443074e-04
# 29197    8.588469e-04
# 29805    1.005437e-04
# 30413    9.701728e-04
# 31021    8.315773e-04
# 31629    5.949398e-05
# 32237    3.926225e-04
# 32845    8.436376e-04
# 33453    9.836108e-05
# 34061    7.464010e-06
# 34669    1.045994e-05
# 35277    7.931658e-06
# 35885    3.366717e-06
# Name: performance_mean, dtype: float64

# %%
result_df = result_df.drop(columns = '_merge')

# %%
result_df.to_csv(os.path.join(result_path, 'group_results.csv'), index=False)
